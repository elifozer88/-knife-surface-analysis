# %% [markdown]
# # 01 - EDA
# Bu notebook veri keşfi için başlangıç hücrelerini içerir.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Örnek: veri yükleme
# df = pd.read_excel('data/raw/data.xlsx')
# df.head()
